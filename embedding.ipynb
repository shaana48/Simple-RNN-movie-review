# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent = ['the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[5955, 4093, 7194, 7788],
#  [5955, 4093, 7194, 649],
#  [5955, 4425, 7194, 6992],
#  [5746, 9748, 3647, 8852, 951],
#  [5746, 9748, 3647, 8852, 8864],
#  [4646, 5955, 9609, 7194, 4593],
#  [9272, 78, 7047, 8852]]

# %% [markdown]
# #### Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8   # Setting max length with help of pad_sequence  if theres only 4 words pad add 3 more zero to make every sent same length
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 5955 4093 7194 7788]
#  [   0    0    0    0 5955 4093 7194  649]
#  [   0    0    0    0 5955 4425 7194 6992]
#  [   0    0    0 5746 9748 3647 8852  951]
#  [   0    0    0 5746 9748 3647 8852 8864]
#  [   0    0    0 4646 5955 9609 7194 4593]
#  [   0    0    0    0 9272   78 7047 8852]]

# %% [markdown]
# ##### feature representation

# %%
dim=10  # 10 dimensions

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\Users\Fathi\anaconda3\envs\venv\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.build(input_shape=(None, sent_length))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# array([[[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.01785454,  0.01638163,  0.04748288, -0.04315161,
#          -0.02166638, -0.04104429, -0.02106272, -0.02505541,
#          -0.01124251,  0.01782301],
#         [-0.03341372,  0.04406771,  0.00535369, -0.03813686,
#          -0.04701018, -0.00592718, -0.02270817, -0.02684375,
#          -0.04766308,  0.03064616],
#         [-0.04656705, -0.00139261,  0.01088382,  0.01202831,
#           0.00641459, -0.03846061, -0.03305116,  0.04723431,
#          -0.01357273, -0.01303162],
#         [ 0.03940401,  0.04866482,  0.00016155, -0.04496373,
#          -0.04896054, -0.00063877,  0.0257519 ,  0.00241793,
#           0.01890577, -0.03272979]],
#
#        [[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.01785454,  0.01638163,  0.04748288, -0.04315161,
#          -0.02166638, -0.04104429, -0.02106272, -0.02505541,
#          -0.01124251,  0.01782301],
#         [-0.03341372,  0.04406771,  0.00535369, -0.03813686,
#          -0.04701018, -0.00592718, -0.02270817, -0.02684375,
#          -0.04766308,  0.03064616],
#         [-0.04656705, -0.00139261,  0.01088382,  0.01202831,
#           0.00641459, -0.03846061, -0.03305116,  0.04723431,
#          -0.01357273, -0.01303162],
#         [-0.04733169,  0.04311562,  0.03399466, -0.00220491,
#          -0.04833372, -0.04094988, -0.02055099, -0.01630267,
#           0.00491946,  0.04935033]],
#
#        [[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.01785454,  0.01638163,  0.04748288, -0.04315161,
#          -0.02166638, -0.04104429, -0.02106272, -0.02505541,
#          -0.01124251,  0.01782301],
#         [-0.04340022, -0.04266071,  0.02985611,  0.02949605,
#          -0.01999672,  0.02185628, -0.03156974,  0.01754315,
#          -0.04019852,  0.01643953],
#         [-0.04656705, -0.00139261,  0.01088382,  0.01202831,
#           0.00641459, -0.03846061, -0.03305116,  0.04723431,
#          -0.01357273, -0.01303162],
#         [ 0.01391542,  0.02151472, -0.04731418,  0.04224033,
#          -0.02569319, -0.01393012,  0.04052002, -0.00521113,
#           0.03201032,  0.02551855]],
#
#        [[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.00350603, -0.00934802,  0.01188217, -0.03822783,
#           0.00828294, -0.00871011,  0.00655968, -0.03526058,
#           0.01508838,  0.03925789],
#         [-0.017141  ,  0.02735436,  0.04309256, -0.04815446,
#           0.00380862,  0.00083011,  0.04649604, -0.00478412,
#           0.02227864,  0.00497746],
#         [-0.00056946,  0.02760441,  0.02764929, -0.02650322,
#          -0.03432685, -0.03404029,  0.03952016,  0.03881026,
#          -0.00268966,  0.04218004],
#         [ 0.01612678,  0.03086576, -0.0489338 ,  0.038534  ,
#          -0.04517609, -0.04038225, -0.04114071, -0.03043885,
#           0.01984392,  0.04982555],
#         [ 0.01265657, -0.00983636, -0.04529374,  0.00423199,
#          -0.02230713, -0.04414144,  0.04818625,  0.02361922,
#          -0.03863238,  0.03708316]],
#
#        [[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.00350603, -0.00934802,  0.01188217, -0.03822783,
#           0.00828294, -0.00871011,  0.00655968, -0.03526058,
#           0.01508838,  0.03925789],
#         [-0.017141  ,  0.02735436,  0.04309256, -0.04815446,
#           0.00380862,  0.00083011,  0.04649604, -0.00478412,
#           0.02227864,  0.00497746],
#         [-0.00056946,  0.02760441,  0.02764929, -0.02650322,
#          -0.03432685, -0.03404029,  0.03952016,  0.03881026,
#          -0.00268966,  0.04218004],
#         [ 0.01612678,  0.03086576, -0.0489338 ,  0.038534  ,
#          -0.04517609, -0.04038225, -0.04114071, -0.03043885,
#           0.01984392,  0.04982555],
#         [-0.00129091,  0.04263398, -0.01951328,  0.01367476,
#           0.01735774,  0.03528999, -0.01315012,  0.01273611,
#           0.00964278, -0.00180066]],
#
#        [[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.01510191,  0.00322423, -0.04049256, -0.02769549,
#           0.03388542,  0.0097353 ,  0.00168683,  0.02229059,
#           0.01827376,  0.04010164],
#         [ 0.01785454,  0.01638163,  0.04748288, -0.04315161,
#          -0.02166638, -0.04104429, -0.02106272, -0.02505541,
#          -0.01124251,  0.01782301],
#         [-0.01225602,  0.00770719,  0.00961312, -0.0438676 ,
#          -0.04090691, -0.0310986 ,  0.04308735, -0.02511944,
#          -0.02199242, -0.0119    ],
#         [-0.04656705, -0.00139261,  0.01088382,  0.01202831,
#           0.00641459, -0.03846061, -0.03305116,  0.04723431,
#          -0.01357273, -0.01303162],
#         [-0.03463405,  0.02619031, -0.04943201,  0.04483887,
#           0.02287035, -0.0465669 , -0.00547047,  0.04012531,
#          -0.03098449, -0.00365813]],
#
#        [[ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.03076202,  0.03785268, -0.01094217, -0.02556604,
#          -0.0131251 ,  0.03417308,  0.02265748,  0.00290173,
#           0.03649205, -0.00833973],
#         [ 0.0062296 ,  0.0354504 ,  0.02280518,  0.00209314,
#          -0.00620103,  0.01697768, -0.00592613, -0.00442566,
#          -0.01623381, -0.02592595],
#         [-0.00715504, -0.04167452, -0.03448987, -0.00627489,
#           0.01712418,  0.00101957, -0.02349141,  0.03596766,
#          -0.03299234,  0.00123715],
#         [ 0.03179443, -0.00386311, -0.0358912 , -0.01662894,
#          -0.02160696, -0.03109385,  0.0401699 , -0.02205223,
#          -0.00819684,  0.02180857],
#         [ 0.01612678,  0.03086576, -0.0489338 ,  0.038534  ,
#          -0.04517609, -0.04038225, -0.04114071, -0.03043885,
#           0.01984392,  0.04982555]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 5955, 4093, 7194, 7788], dtype=int32)
